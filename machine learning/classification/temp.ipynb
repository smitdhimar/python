# %% [markdown]
# <a href="https://colab.research.google.com/github/smitdhimar/python/blob/main/machine%20learning/classification/temp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/smitdhimar/python.git
# Out:
# Cloning into 'python'...
# remote: Enumerating objects: 167, done.
# remote: Counting objects: 100% (167/167), done.
# remote: Compressing objects: 100% (148/148), done.
# remote: Total 167 (delta 18), reused 154 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (167/167), 5.79 MiB | 8.65 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
